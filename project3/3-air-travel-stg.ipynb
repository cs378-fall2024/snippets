# %% [markdown]
# ### staging dataset

# %%
from google.cloud import bigquery

project_id = "cs378-fa2024"
dataset = "air_travel_stg"
region = "us-central1"

bq_client = bigquery.Client()

dataset_id = bigquery.Dataset(f"{project_id}.{dataset}")
dataset_id.location = region
resp = bq_client.create_dataset(dataset_id, exists_ok=True)
print("Created dataset {}.{}".format(bq_client.project, resp.dataset_id))
# Out:
# Created dataset cs378-fa2024.air_travel_stg

# %% [markdown]
# ### `aircrafts` table

# %% [markdown]
# ##### Replace `'\\N'` with null

# %%
# %%bigquery
# select aircraft_name, iata_code,
# case icao_code when '\\N' then null else icao_code end as icao_code,
#   _data_source, _load_time
# from air_travel_raw.aircrafts;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                       aircraft_name iata_code icao_code  \
# 0                                       Airbus A330       330      None
# 1                                       Airbus A340       340      None
# 2                                       Airbus A350       350      None
# 3                                       Airbus A380       380      None
# 4                                           BAe 146       146      None
# ..                                              ...       ...       ...
# 241                                  Tupolev Tu-204       T20      T204
# 242  Pilatus Britten-Norman BN-2A Mk III Trislander       BNT      TRIS
# 243                                 Yakovlev Yak-40       YK4      YK40
# 244                                 Yakovlev Yak-42       YK2      YK42
# 245                                      NAMC YS-11       YS1      YS11
#
#     _data_source                       _load_time
# 0    openflights 2024-08-25 16:15:09.744963+00:00
# 1    openflights 2024-08-25 16:15:09.744963+00:00
# 2    openflights 2024-08-25 16:15:09.744963+00:00
# 3    openflights 2024-08-25 16:15:09.744963+00:00
# 4    openflights 2024-08-25 16:15:09.744963+00:00
# ..           ...                              ...
# 241  openflights 2024-08-25 16:15:09.744963+00:00
# 242  openflights 2024-08-25 16:15:09.744963+00:00
# 243  openflights 2024-08-25 16:15:09.744963+00:00
# 244  openflights 2024-08-25 16:15:09.744963+00:00
# 245  openflights 2024-08-25 16:15:09.744963+00:00
#
# [246 rows x 5 columns]

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.aircrafts as
#   select aircraft_name as name,
#   case iata_code when '\\N' then null else iata_code end as iata,
#   case icao_code when '\\N' then null else icao_code end as icao,
#   _data_source,
#   _load_time
#   from air_travel_raw.aircrafts;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airlines` table

# %% [markdown]
# ##### Replace `'\\N'` with null

# %%
# %%bigquery
# select airline_id as id,
# name,
# case alias when '\\N' then null else alias end as alias,
# iata, icao, callsign,
# case country when '\\N' then null else country end as country,
# active, _data_source, _load_time
# from air_travel_raw.airlines;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          id                            name alias iata icao          callsign  \
# 0       415           Aerojet de Costa Rica  None       ARJ              S.A.
# 1      1509               Bellview Airlines  None       BVU      Sierra Leone
# 2      1516                      BAX Global  None   8W
# 3      2080         Electronic Data Systems  None        1Y
# 4      2636  Gulf African Airlines - Gambia  None       GUF      GULF AFRICAN
# ...     ...                             ...   ...  ...  ...               ...
# 6157   2773              Hong Kong Airlines  None   HX  CRK          BAUHINIA
# 6158   2774       Hong Kong Express Airways  None   UO  HKE  HONGKONG SHUTTLE
# 6159   3233                    Lao Airlines  None   QV  LAO               LAO
# 6160  11724                         SVG Air             SVG        Grenadines
# 6161    998                       Air Koryo  None   JS  KOR         AIR KORYO
#
#                                     country  active _data_source  \
# 0                                             False  openflights
# 1                                             False  openflights
# 2                                             False  openflights
# 3                                             False  openflights
# 4                                             False  openflights
# ...                                     ...     ...          ...
# 6157                 Hong Kong SAR of China    True  openflights
# 6158                 Hong Kong SAR of China    True  openflights
# 6159        Lao Peoples Democratic Republic    True  openflights
# 6160       Saint Vincent and the Grenadines    True  openflights
# 6161  Democratic People's Republic of Korea    True  openflights
#
#                            _load_time
# 0    2024-08-25 15:52:55.956309+00:00
# 1    2024-08-25 15:52:55.956309+00:00
# 2    2024-08-25 15:52:55.956309+00:00
# 3    2024-08-25 15:52:55.956309+00:00
# 4    2024-08-25 15:52:55.956309+00:00
# ...                               ...
# 6157 2024-08-25 15:52:55.956309+00:00
# 6158 2024-08-25 15:52:55.956309+00:00
# 6159 2024-08-25 15:52:55.956309+00:00
# 6160 2024-08-25 15:52:55.956309+00:00
# 6161 2024-08-25 15:52:55.956309+00:00
#
# [6162 rows x 10 columns]

# %% [markdown]
# ##### Look for empty strings

# %%
# %%bigquery
# select count(*) as empty_alias
# from air_travel_raw.airlines
# where alias = '';
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_alias
# 0          505

# %%
# %%bigquery
# select count(*) as empty_country
# from air_travel_raw.airlines
# where country = '';
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_country
# 0             15

# %% [markdown]
# ##### Putting it all together

# %%
# %%bigquery
# select airline_id as id,
# name,
# case alias
#   when '\\N' then null
#   when '' then null
#   else alias
#   end as alias,
# case iata
#   when '' then null
#   else iata
#   end as iata,
# case icao
#   when '' then null
#   else icao
#   end as icao,
# case callsign
#   when '' then null
#   else callsign
#   end as callsign,
# case country
#   when '\\N' then null
#   when '' then null
#   else country end as country,
# active, _data_source, _load_time
# from air_travel_raw.airlines;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          id                            name alias  iata  icao  \
# 0       415           Aerojet de Costa Rica  None  None   ARJ
# 1      1509               Bellview Airlines  None  None   BVU
# 2      1516                      BAX Global  None    8W  None
# 3      2080         Electronic Data Systems  None  None    1Y
# 4      2636  Gulf African Airlines - Gambia  None  None   GUF
# ...     ...                             ...   ...   ...   ...
# 6157   2773              Hong Kong Airlines  None    HX   CRK
# 6158   2774       Hong Kong Express Airways  None    UO   HKE
# 6159   3233                    Lao Airlines  None    QV   LAO
# 6160  11724                         SVG Air  None  None   SVG
# 6161    998                       Air Koryo  None    JS   KOR
#
#               callsign                                country  active  \
# 0                 S.A.                                   None   False
# 1         Sierra Leone                                   None   False
# 2                 None                                   None   False
# 3                 None                                   None   False
# 4         GULF AFRICAN                                   None   False
# ...                ...                                    ...     ...
# 6157          BAUHINIA                 Hong Kong SAR of China    True
# 6158  HONGKONG SHUTTLE                 Hong Kong SAR of China    True
# 6159               LAO        Lao Peoples Democratic Republic    True
# 6160        Grenadines       Saint Vincent and the Grenadines    True
# 6161         AIR KORYO  Democratic People's Republic of Korea    True
#
#      _data_source                       _load_time
# 0     openflights 2024-08-25 15:52:55.956309+00:00
# 1     openflights 2024-08-25 15:52:55.956309+00:00
# 2     openflights 2024-08-25 15:52:55.956309+00:00
# 3     openflights 2024-08-25 15:52:55.956309+00:00
# 4     openflights 2024-08-25 15:52:55.956309+00:00
# ...           ...                              ...
# 6157  openflights 2024-08-25 15:52:55.956309+00:00
# 6158  openflights 2024-08-25 15:52:55.956309+00:00
# 6159  openflights 2024-08-25 15:52:55.956309+00:00
# 6160  openflights 2024-08-25 15:52:55.956309+00:00
# 6161  openflights 2024-08-25 15:52:55.956309+00:00
#
# [6162 rows x 10 columns]

# %% [markdown]
# ##### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.airlines as
#   select airline_id as id,
#   name,
#   case alias
#     when '\\N' then null
#     when '' then null
#     else alias
#     end as alias,
#   case iata
#     when '' then null
#     else iata
#     end as iata,
#   case icao
#     when '' then null
#     else icao
#     end as icao,
#   case callsign
#     when '' then null
#     else callsign
#     end as callsign,
#   case country
#     when '\\N' then null
#     when '' then null
#     else country end as country,
#   active, _data_source, _load_time
#   from air_travel_raw.airlines;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airport_businesses` table

# %% [markdown]
# #### Profile category values

# %%
# %%bigquery
# select distinct category
# from air_travel_raw.airport_businesses
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                category
# 0                   ATM
# 1        Administration
# 2           Air Service
# 3    Air Transportation
# 4               Airline
# ..                  ...
# 184          restaurant
# 185            security
# 186    shipping company
# 187            shopping
# 188      transportation
#
# [189 rows x 1 columns]

# %%
# %%bigquery
# select category, count(*) as airline_categories
# from air_travel_raw.airport_businesses
# where category like '%Airline%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                   category  airline_categories
# 0                  Airline                 108
# 1   Airline Club & Lounges                   3
# 2           Airline Office                   2
# 3         Airline Services                   1
# 4  Airline Ticket Counters                   1
# 5        Airline Ticketing                   3
# 6                 Airlines                  29

# %%
# %%bigquery
# select category, count(*) as airport_categories
# from air_travel_raw.airport_businesses
# where category like '%Airport%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            category  airport_categories
# 0  Airport Facility                   1
# 1  Airport Security                   2
# 2   Airport Service                  40
# 3  Airport Services                 108

# %%
# %%bigquery
# select category, count(*) as food_categories
# from air_travel_raw.airport_businesses
# where category like '%Food%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        category  food_categories
# 0     Fast Food               13
# 1          Food                2
# 2  Food & Drink                4
# 3    Food Court                2
# 4    Food/Drink                3

# %%
# %%bigquery
# select category, count(*) as news_categories
# from air_travel_raw.airport_businesses
# where category like '%News%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                 category  news_categories
# 0                   News                2
# 1           News & Media                5
# 2             News Kiosk                1
# 3             News Stand                2
# 4              Newsagent                1
# 5              Newsstand               39
# 6  Newsstand/Coffee Shop                1

# %%
# %%bigquery
# select category, count(*) as shop_categories
# from air_travel_raw.airport_businesses
# where category like 'Shop%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    category  shop_categories
# 0      Shop                2
# 1  Shopping              160

# %% [markdown]
# #### Standardize the category field with LLM

# %%
import vertexai
from vertexai.generative_models import GenerativeModel, Part

project_id = "cs378-fa2024"
region = "us-central1"
model_name = "gemini-1.5-flash-001"
prompt = """Look for categories that have similar meanings, but are distinct from each other.
Replace them with a standard category.
For example, some records have a category of 'Airline Ticket Counters' and others
have a category of 'Airline Ticketing' and they both mean similar things.
Map 'Airline Ticket Counters' to 'Airline Ticketing'.
Return the entire list of original categories along with the new categories.
Format the results as json with the schema: current_category:string, new_category:string.

Below is the list of current_categories:
Airline
Airline Club & Lounges
Airline Office
Airline Services
Airline Ticket Counters
Airline Ticketing
Airlines
"""

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name)
resp = model.generate_content([prompt])
resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
print(resp_text)
# Out:
# [  {    "current_category": "Airline",    "new_category": "Airlines"  },  {    "current_category": "Airline Club & Lounges",    "new_category": "Airline Services"  },  {    "current_category": "Airline Office",    "new_category": "Airlines"   },  {    "current_category": "Airline Services",    "new_category": "Airline Services"  },  {    "current_category": "Airline Ticket Counters",    "new_category": "Airline Ticketing"  },  {    "current_category": "Airline Ticketing",    "new_category": "Airline Ticketing"  },  {    "current_category": "Airlines",    "new_category": "Airlines"  }]

# %% [markdown]
# #### Refine the prompt and make it more dynamic

# %%
import json
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery

project_id = "cs378-fa2024"
region = "us-central1"
model_name = "gemini-1.5-flash-001"
prompt = """Go through this list of categories and look for categories that have similar meanings, but were given different names.
For example, 'Airline Ticket Counters' and 'Airline Ticketing' have similar meanings and 'Mother Room and 'Mother's Room' have similar meanings.
Suggest a standard category, mapping the current one to the new one.
Return the list of original categories along with their new categories.
Format the results as a json object with the schema: current_category:string, new_category:string.
Do not include any unchanged categories with your answer.
Do not include an explanation with your answer.
"""
category_sql = """select distinct category from air_travel_raw.airport_businesses
where category like 'R%' order by category limit 30"""

airport_businesses_sql = """select airport_code, terminal, business, category, location
from air_travel_raw.airport_businesses where category like 'R%'
and category != 'Restaurant'
order by category limit 30"""

bq_client = bigquery.Client()
rows = bq_client.query_and_wait(category_sql)

category_list = []
for row in rows:
    category_list.append(row["category"])
category_str = '\n'.join(category_list)
print("category_str:", category_str)

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name)
resp = model.generate_content([category_str, prompt])
resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
print(resp_text)
categories = json.loads(resp_text)
print("categories:", categories)

# filter out any unchanged categories
replacements = {}
for old, new in categories.items():
    if old == new:
        continue
    else:
        replacements[old] = new
print("replacements:", replacements)

df = bq_client.query_and_wait(airport_businesses_sql).to_dataframe()
print("orig df:", df)

df["category"] = df["category"].map(replacements).fillna(df["category"])
print("new df:", df)
# Out:
# category_str: Rental
# Restaurant
# Restroom
# Restrooms
# Retail
# {  "Restroom": "Restrooms",  "Retail": "Restaurant"}
# categories: {'Restroom': 'Restrooms', 'Retail': 'Restaurant'}
# replacements: {'Restroom': 'Restrooms', 'Retail': 'Restaurant'}
# orig df:    airport_code terminal                 business   category  \
# 0           syr        1  Automated Rental Lounge     Rental
# 1           abq        1             Nursing Room   Restroom
# 2           pgd        1            Mother's Room  Restrooms
# 3           blv        1         Family Restrooms  Restrooms
# 4           atw        1              Mother Room  Restrooms
# 5           atw        1              Mother Room  Restrooms
# 6           gtr        1         Vending machines     Retail
# 7           chs        1               Amazon One     Retail
# 8           fsd        1                Gift Shop     Retail
# 9           fsd        1                Gift Shop     Retail
# 10          lax        3           Hudson Nonstop     Retail
# 11          gtr        1         Vending machines     Retail
# 12          gtr        1         Vending machines     Retail
# 13          abq        1               Misc Shops     Retail
#
#                            location
# 0   Terminal 1 Level 1 near Gate 15
# 1                       Third Floor
# 2                            Gate 2
# 3              Level 2 near Gates B
# 4                       Near Gate 6
# 5                       Near Gate 2
# 6                     Gates B3 & B4
# 7                      Near gate A1
# 8                      Near Gate 15
# 9                       Near Gate 5
# 10                         Gate 37B
# 11                          Gate B2
# 12                          Gate B1
# 13                          Gate A2
# new df:    airport_code terminal                 business    category  \
# 0           syr        1  Automated Rental Lounge      Rental
# 1           abq        1             Nursing Room   Restrooms
# 2           pgd        1            Mother's Room   Restrooms
# 3           blv        1         Family Restrooms   Restrooms
# 4           atw        1              Mother Room   Restrooms
# 5           atw        1              Mother Room   Restrooms
# 6           gtr        1         Vending machines  Restaurant
# 7           chs        1               Amazon One  Restaurant
# 8           fsd        1                Gift Shop  Restaurant
# 9           fsd        1                Gift Shop  Restaurant
# 10          lax        3           Hudson Nonstop  Restaurant
# 11          gtr        1         Vending machines  Restaurant
# 12          gtr        1         Vending machines  Restaurant
# 13          abq        1               Misc Shops  Restaurant
#
#                            location
# 0   Terminal 1 Level 1 near Gate 15
# 1                       Third Floor
# 2                            Gate 2
# 3              Level 2 near Gates B
# 4                       Near Gate 6
# 5                       Near Gate 2
# 6                     Gates B3 & B4
# 7                      Near gate A1
# 8                      Near Gate 15
# 9                       Near Gate 5
# 10                         Gate 37B
# 11                          Gate B2
# 12                          Gate B1
# 13                          Gate A2

# %% [markdown]
# #### Process entire table and save results to BQ

# %%
import json
import pandas_gbq
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery

project_id = "cs378-fa2024"
region = "us-central1"
model_name = "gemini-1.5-flash-001"
prompt = """Go through this list of categories and look for categories that have similar meanings, but were given different names.
For example, 'Airline Ticket Counters' and 'Airline Ticketing' have similar meanings and 'Mother Room and 'Mother's Room' have similar meanings.
Suggest a standard category, mapping the current one to the new one.
Return the list of original categories along with their new categories.
Format the results as a json object with the schema: current_category:string, new_category:string.
Do not include any unchanged categories with your answer.
Do not include an explanation with your answer.
"""
category_sql = "select distinct category from air_travel_raw.airport_businesses"

airport_businesses_sql = "select * from air_travel_raw.airport_businesses"

bq_client = bigquery.Client()
rows = bq_client.query_and_wait(category_sql)

category_list = []
for row in rows:
    category_list.append(row["category"])
category_str = '\n'.join(category_list)
#print("category_str:", category_str)

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name)
resp = model.generate_content([category_str, prompt])
resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
print(resp_text)
categories = json.loads(resp_text)
print(type(categories))

replacements = {} # will store the new categories

# categories can be either a dictionary or list type (depending on what LLM decides to do!)
if type(categories) == dict:
    for old, new in categories.items():
        if old == new:
            continue
        else:
            replacements[old] = new

if type(categories) == list:
    for cat_entry in categories:
        if cat_entry['current_category'] == cat_entry['new_category']:
            continue
        else:
            replacements[cat_entry['current_category']] = cat_entry['new_category']

print("replacements:", replacements)

# read the table and merge in the changes
df = bq_client.query_and_wait(airport_businesses_sql).to_dataframe()
print("orig df:", df)

df["category"] = df["category"].map(replacements).fillna(df["category"])
print("new df:", df)

table_id = "air_travel_stg.tmp_airport_businesses"
pandas_gbq.to_gbq(df, table_id, project_id=project_id, if_exists="replace")
# Out:
# {  "Airline Ticket Counters": "Airline Ticketing",  "Beverage": "Food & Drink",  "Snacks": "Food & Drink",  "Food/Drink": "Food & Drink",  "News & Media": "News",  "Banking": "Financial Services",  "Public Space": "Airport Facility",  "Work Space": "Office",  "Government": "Administration",  "Convenience Store": "Shop",  "Community": "Airport Facility",  "Airline Ticketing": "Airline Services",  "Dessert": "Food & Drink",  "Pizza": "Food & Drink",  "Shoe Shine": "Services",  "Cosmetics": "Beauty Products",  "Sunglasses": "Accessories",  "Salon": "Beauty Services",  "Liquor Store": "Shop",  "Lottery": "Other",  "Jewelry": "Accessories",  "Sporting Goods": "Shop",  "Travel Agency": "Services",  "Sporting Goods Store": "Shop",  "Pretzels": "Food & Drink",  "Wine Bar": "Bar/Restaurant",  "Grocery Store": "Shop",  "Newsagent": "News",  "Café": "Coffee Shop",  "Observation Point": "Airport Facility",  "Juice Bar": "Food & Drink",  "Phone Service": "Communication",  "Healthcare": "Medical",  "Mail": "Shipping",  "Seafood Restaurant": "Restaurant",  "Sandwich Shop": "Food & Drink",  "Airport Security": "Security",  "Conference Room": "Meeting Space",  "Business": "Services",  "Customer Service": "Services",  "Candy Shop": "Shop",  "Bookstore": "Shop",  "shipping company": "Shipping",  "Clothing Store": "Shop",  "Ice Cream Shop": "Food & Drink",  "Newsstand/Coffee Shop": "Newsstand",  "Cosmetics Store": "Shop",  "Spa": "Beauty Services",  "Spiritual": "Other",  "Fitness": "Services",  "Information Desk": "Information",  "Phone": "Communication",  "Shipping": "Services",  "Food": "Food & Drink",  "Grocery": "Shop",  "Food & Drink": "Dining",  "police": "Security",  "gift shop": "Gift Shop",  "News Kiosk": "News",  "Gift shop": "Gift Shop",  "ATM": "Financial Services",  "Air Transportation": "Airline Services",  "Concession": "Food & Drink",  "Shop": "Retail",  "Souvenir Shop": "Gift Shop",  "Airline Ticketing": "Airline Services",  "Restroom": "Restrooms",  "Administration": "Services",  "conference": "Meeting Space",  "art": "Art Exhibit",  "family": "Other",  "security": "Security",  "restaurant": "Restaurant",  "Airport Facility": "Airport Services",  "Information Center": "Information",  "transportation": "Transportation",  "Baby care": "Baby Care",  "Meeting Space": "Services",  "Pet Relief": "Pet Services",  "Pretzel Shop": "Food & Drink",  "Coffee & Doughnuts": "Food & Drink",  "Food Court": "Food & Drink",  "News Stand": "News",  "Popcorn Shop": "Food & Drink",  "Things to Do": "Entertainment",  "Airline Club & Lounges": "Lounge",  "Airline Office": "Airline Services",  "Baggage Handling": "Baggage Service",  "Vacant": "Other",  "Burger Restaurant": "Restaurant",  "Brewery/Pub": "Bar/Restaurant",  "News": "Media",  "Things to do": "Entertainment",  "Dinning": "Dining",  "Duty Free": "Shop",  "Immigration": "Administration",  "Art Exhibit": "Art",  "Media": "Entertainment",  "airline cargo": "Cargo Services",  "Financial": "Financial Services",  "Communication": "Services",  "Luxury Goods": "Shop",  "Lingerie": "Clothing",  "Chinese": "Restaurant",  "Clothing": "Shop",  "Tattoo": "Other",  "Sports Bar": "Bar/Restaurant",  "Mexican": "Restaurant",  "Burger": "Food & Drink",  "Fashion": "Shop",  "Japanese": "Restaurant",  "Handbags": "Accessories",  "Asian": "Restaurant",  "Luggage": "Baggage Service",  "Escalator": "Transportation",  "Italian Restaurant": "Restaurant",  "Sushi Restaurant": "Restaurant",  "Mexican Restaurant": "Restaurant",  "Art": "Art Exhibit",  "Things To Do": "Entertainment",  "Market": "Shop",  "Bar/Restaurant": "Dining",  "Airline Services": "Airlines",  "Parking": "Transportation",  "Vending": "Vending Machines",  "Information": "Services",  "Meditation": "Other",  "Gifts": "Shop",  "Beauty Products": "Shop",  "Cargo Services": "Services",  "Coffee shop": "Coffee Shop",  "Jewelry Store": "Shop",  "Museum": "Art Exhibit",  "Chiropractor": "Medical",  "Chocolate Shop": "Shop",  "lounge": "Lounge",  "Emergency ...
# <class 'dict'>
# replacements: {'Airline Ticket Counters': 'Airline Ticketing', 'Beverage': 'Food & Drink', 'Snacks': 'Food & Drink', 'Food/Drink': 'Food & Drink', 'News & Media': 'News', 'Banking': 'Financial Services', 'Public Space': 'Airport Facility', 'Work Space': 'Office', 'Government': 'Administration', 'Convenience Store': 'Shop', 'Community': 'Airport Facility', 'Airline Ticketing': 'Airline Services', 'Dessert': 'Food & Drink', 'Pizza': 'Food & Drink', 'Shoe Shine': 'Services', 'Cosmetics': 'Beauty Products', 'Sunglasses': 'Accessories', 'Salon': 'Beauty Services', 'Liquor Store': 'Shop', 'Lottery': 'Other', 'Jewelry': 'Accessories', 'Sporting Goods': 'Shop', 'Travel Agency': 'Services', 'Sporting Goods Store': 'Shop', 'Pretzels': 'Food & Drink', 'Wine Bar': 'Bar/Restaurant', 'Grocery Store': 'Shop', 'Newsagent': 'News', 'Café': 'Coffee Shop', 'Observation Point': 'Airport Facility', 'Juice Bar': 'Food & Drink', 'Phone Service': 'Communication', 'Healthcare': 'Medical', 'Mail': 'Shipping', 'Seafood Restaurant': 'Restaurant', 'Sandwich Shop': 'Food & Drink', 'Airport Security': 'Security', 'Conference Room': 'Meeting Space', 'Business': 'Services', 'Customer Service': 'Services', 'Candy Shop': 'Shop', 'Bookstore': 'Shop', 'shipping company': 'Shipping', 'Clothing Store': 'Shop', 'Ice Cream Shop': 'Food & Drink', 'Newsstand/Coffee Shop': 'Newsstand', 'Cosmetics Store': 'Shop', 'Spa': 'Beauty Services', 'Spiritual': 'Other', 'Fitness': 'Services', 'Information Desk': 'Information', 'Phone': 'Communication', 'Shipping': 'Services', 'Food': 'Food & Drink', 'Grocery': 'Shop', 'Food & Drink': 'Dining', 'police': 'Security', 'gift shop': 'Gift Shop', 'News Kiosk': 'News', 'Gift shop': 'Gift Shop', 'ATM': 'Financial Services', 'Air Transportation': 'Airline Services', 'Concession': 'Food & Drink', 'Shop': 'Retail', 'Souvenir Shop': 'Gift Shop', 'Restroom': 'Restrooms', 'Administration': 'Services', 'conference': 'Meeting Space', 'art': 'Art Exhibit', 'family': 'Other', 'security': 'Security', 'restaurant': 'Restaurant', 'Airport Facility': 'Airport Services', 'Information Center': 'Information', 'transportation': 'Transportation', 'Baby care': 'Baby Care', 'Meeting Space': 'Services', 'Pet Relief': 'Pet Services', 'Pretzel Shop': 'Food & Drink', 'Coffee & Doughnuts': 'Food & Drink', 'Food Court': 'Food & Drink', 'News Stand': 'News', 'Popcorn Shop': 'Food & Drink', 'Things to Do': 'Entertainment', 'Airline Club & Lounges': 'Lounge', 'Airline Office': 'Airline Services', 'Baggage Handling': 'Baggage Service', 'Vacant': 'Other', 'Burger Restaurant': 'Restaurant', 'Brewery/Pub': 'Bar/Restaurant', 'News': 'Media', 'Things to do': 'Entertainment', 'Dinning': 'Dining', 'Duty Free': 'Shop', 'Immigration': 'Administration', 'Art Exhibit': 'Art', 'Media': 'Entertainment', 'airline cargo': 'Cargo Services', 'Financial': 'Financial Services', 'Communication': 'Services', 'Luxury Goods': 'Shop', 'Lingerie': 'Clothing', 'Chinese': 'Restaurant', 'Clothing': 'Shop', 'Tattoo': 'Other', 'Sports Bar': 'Bar/Restaurant', 'Mexican': 'Restaurant', 'Burger': 'Food & Drink', 'Fashion': 'Shop', 'Japanese': 'Restaurant', 'Handbags': 'Accessories', 'Asian': 'Restaurant', 'Luggage': 'Baggage Service', 'Escalator': 'Transportation', 'Italian Restaurant': 'Restaurant', 'Sushi Restaurant': 'Restaurant', 'Mexican Restaurant': 'Restaurant', 'Art': 'Art Exhibit', 'Things To Do': 'Entertainment', 'Market': 'Shop', 'Bar/Restaurant': 'Dining', 'Airline Services': 'Airlines', 'Parking': 'Transportation', 'Vending': 'Vending Machines', 'Information': 'Services', 'Meditation': 'Other', 'Gifts': 'Shop', 'Beauty Products': 'Shop', 'Cargo Services': 'Services', 'Coffee shop': 'Coffee Shop', 'Jewelry Store': 'Shop', 'Museum': 'Art Exhibit', 'Chiropractor': 'Medical', 'Chocolate Shop': 'Shop', 'lounge': 'Lounge', 'Emergency': 'Other', 'Pet Services': 'Services', 'Baby Care': 'Services', 'Air Service': 'Airlines', 'Water Refilling': 'Services', 'Exhibits': 'Art Exhibit', 'Rental': 'Serv ...
# orig df:      airport_code terminal                       business            category  \
# 0             pgd        1                            ATM  Financial Services
# 1             ege        1   Delta Baggage Service Office     Baggage Service
# 2             pgd        1                  Mother's Room           Restrooms
# 3             ege        1  United Baggage Service Office     Baggage Service
# 4             cwa        1                            AED             Medical
# ...           ...      ...                            ...                 ...
# 1569          hou        1                         iStore   Electronics Store
# 1570          pwm        1               Best Buy Express   Electronics Store
# 1571          lax        6                         Belkin   Electronics Store
# 1572          las        1                     Brookstone   Electronics Store
# 1573          syr        1                         eSavvy   Electronics Store
#
#                              location menu_items  _data_source  \
# 0                              Gate 1       None  airportguide
# 1                              Gate 1       None  airportguide
# 2                              Gate 2       None  airportguide
# 3                              Gate 2       None  airportguide
# 4                              Gate 2       None  airportguide
# ...                               ...        ...           ...
# 1569                        Gates 1-4       None  airportguide
# 1570                     Near Gate 11       None  airportguide
# 1571                     Near gate 60       None  airportguide
# 1572               Terminal 1 Level 1       None  airportguide
# 1573  Terminal 1 Level 2 near Gate 10       None  airportguide
#
#                            _load_time
# 0    2024-08-25 15:16:58.467182+00:00
# 1    2024-08-25 15:16:58.467182+00:00
# 2    2024-08-25 15:16:58.467182+00:00
# 3    2024-08-25 15:16:58.467182+00:00
# 4    2024-08-25 15:16:58.467182+00:00
# ...                               ...
# 1569 2024-08-25 15:16:58.467182+00:00
# 1570 2024-08-25 15:16:58.467182+00:00
# 1571 2024-08-25 15:16:58.467182+00:00
# 1572 2024-08-25 15:16:58.467182+00:00
# 1573 2024-08-25 15:16:58.467182+00:00
#
# [1574 rows x 8 columns]
# new df:      airport_code terminal                       business            category  \
# 0             pgd        1                            ATM  Financial Services
# 1             ege        1   Delta Baggage Service Office     Baggage Service
# 2             pgd        1                  Mother's Room           Restrooms
# 3             ege        1  United Baggage Service Office     Baggage Service
# 4             cwa        1                            AED             Medical
# ...           ...      ...                            ...                 ...
# 1569          hou        1                         iStore                Shop
# 1570          pwm        1               Best Buy Express                Shop
# 1571          lax        6                         Belkin                Shop
# 1572          las        1                     Brookstone                Shop
# 1573          syr        1                         eSavvy                Shop
#
#                              location menu_items  _data_source  \
# 0                              Gate 1       None  airportguide
# 1                              Gate 1       None  airportguide
# 2                              Gate 2       None  airportguide
# 3                              Gate 2       None  airportguide
# 4                              Gate 2       None  airportguide
# ...                               ...        ...           ...
# 1569                        Gates 1-4       None  airportguide
# 1570                     Near Gate 11       None  airportguide
# 1571                     Near gate 60       None  airportguide
# 1572               Terminal 1 Level 1       None  airportguide
# 1573  Terminal 1 Level 2 near Gate 10       None  airportguide
#
#                            _load_time
# 0    2024-08-25 15:16:58.467182+00:00
# 1    2024-08-25 15:16:58.467182+00:00
# 2    2024-08-25 15:16:58.467182+00:00
# 3    2024-08-25 15:16:58.467182+00:00
# 4    2024-08-25 15:16:58.467182+00:00
# ...                               ...
# 1569 2024-08-25 15:16:58.467182+00:00
# 1570 2024-08-25 15:16:58.467182+00:00
# 1571 2024-08-25 15:16:58.467182+00:00
# 1572 2024-08-25 15:16:58.467182+00:00
# 1573 2024-08-25 15:16:58.467182+00:00
#
# [1574 rows x 8 columns]
# 100%|██████████| 1/1 [00:00<00:00, 5454.23it/s]

# %% [markdown]
# #### Check the output table

# %%
# %%bigquery
# select distinct category from air_travel_stg.tmp_airport_businesses order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#               category
# 0          Accessories
# 1       Administration
# 2     Airline Services
# 3    Airline Ticketing
# 4             Airlines
# 5     Airport Facility
# 6     Airport Services
# 7                  Art
# 8          Art Exhibit
# 9            Baby Care
# 10     Baggage Service
# 11                Bank
# 12      Bar/Restaurant
# 13     Beauty Products
# 14     Beauty Services
# 15      Cargo Services
# 16            Clothing
# 17         Coffee Shop
# 18       Communication
# 19              Dining
# 20      Duty Free Shop
# 21       Entertainment
# 22  Financial Services
# 23        Food & Drink
# 24           Gift Shop
# 25         Information
# 26              Lounge
# 27          Management
# 28               Media
# 29             Medical
# 30        Meeting Room
# 31       Meeting Space
# 32                News
# 33           Newsstand
# 34              Office
# 35               Other
# 36        Pet Services
# 37          Restaurant
# 38           Restrooms
# 39              Retail
# 40             Seating
# 41            Security
# 42            Services
# 43            Shipping
# 44                Shop
# 45            Shopping
# 46      Transportation
# 47    Vending Machines
# 48             parking

# %% [markdown]
# #### Now do the same thing with the business names, i.e. standardize them to reduce inconsistent spellings

# %%
import json
import pandas_gbq
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery

project_id = "cs378-fa2024"
region = "us-central1"
model_name = "gemini-1.5-flash-001"
prompt = """Go through this list of business names and standardize them to remove the variations in spelling.
For example, 'Sweet Jill Bakery' and 'Sweet Jill's Bakery' both refer to the same business, so standardize on one or the other.
Another example is, 'Alaska Airline' and 'Alaska Airlines'. Since they both refer to the same business, standardize on 'Alaska Airlines'.
Suggest a standard name, mapping the current one to the new one.
Return the list of original business names along with their new names.
Format the results as a json object with the schema: current_name:string, new_new:string.
Do not include any unchanged business names with your answer.
Do not include an explanation with your answer.
"""
business_names_sql = "select distinct business from air_travel_stg.tmp_airport_businesses order by business"

airport_businesses_sql = "select * from air_travel_stg.tmp_airport_businesses"


def do_inference(input_str):

    vertexai.init(project=project_id, location=region)
    model = GenerativeModel(model_name)
    resp = model.generate_content([input_str, prompt])
    resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
    print(resp_text)

    names = json.loads(resp_text)
    print(type(names))

    replacements = {}

    # names can be either a dictionary or list type (depending on what the LLM decides to do!)
    if type(names) == dict:
        for old, new in names.items():
            if old == new:
                continue
            else:
                replacements[old] = new

    if type(names) == list:
        for name_entry in names:
            if name_entry['current_name'] == name_entry['new_name']:
                continue
            else:
                replacements[cat_entry['current_name']] = cat_entry['new_name']

    return replacements


bq_client = bigquery.Client()
rows = bq_client.query_and_wait(business_names_sql)

batch_size = 500
business_names = []
combined_replacements = {}

for i, row in enumerate(rows):

    business_names.append(row["business"])

    if i > 0 and i % batch_size == 0:
        # process batch
        print("processing batch")
        business_names_str = '\n'.join(business_names)
        replacements = do_inference(business_names_str)
        combined_replacements.update(replacements)

        # reset business_names to process next batch
        business_names = []

if len(business_names) > 0:
    print("processing last batch")
    business_names_str = '\n'.join(business_names)
    replacements = do_inference(business_names_str)
    combined_replacements.update(replacements)

print("replacements:", replacements)

# read the table and merge in the changes
df = bq_client.query_and_wait(airport_businesses_sql).to_dataframe()
print("orig df:", df)

df["business"] = df["business"].map(replacements).fillna(df["business"])
print("new df:", df)

table_id = "air_travel_stg.airport_businesses" # output table
pandas_gbq.to_gbq(df, table_id, project_id=project_id, if_exists="replace")
# Out:
# processing batch
# {"13th Street Pub and Grill": "13th Street Pub","3 Daughters Brewing at PIE": "3 Daughters Brewing","49 Mile Market": "49th Mile Market","Air Canada Airlines": "Air Canada","Airline Ticketing Lobbe": "Airline Ticketing","Airport Administration Office": "Airport Administration","Airport Management Offices": "Airport Management","Airport Offices": "Airport Office","Alamo Rent A Car": "Alamo Car Rental","Alamo Rental Car": "Alamo Car Rental","Alaska Airline": "Alaska Airlines","Alaska Airlines Bag Claim Office": "Alaska Airlines Baggage Claim","Alaska Airlines Lounge": "Alaska Airlines Lounge","Alaska Airlines Ticketing": "Alaska Airlines Ticketing","Alaska Offices": "Alaska Office","Alaska Seaplanes": "Alaska Seaplane","Alaska Ticketing": "Alaska Airlines Ticketing","Allegiant Air": "Allegiant Airlines","Allegiant Airline": "Allegiant Airlines","American Air": "American Airlines","American Air Lines": "American Airlines","American Airline": "American Airlines","American Airlines Admirals Club": "American Airlines Admirals Club","American Airlines Bag Claim Office": "American Airlines Baggage Claim","American Airlines Customer Service": "American Airlines Customer Service","American Airlines Inc": "American Airlines","American Airlines Ticketing": "American Airlines Ticketing","American Baggage Office": "American Airlines Baggage Claim","American Baggage Service Office": "American Airlines Baggage Claim","American Eagle Connection": "American Eagle","American Express - The Centurion Lounge": "American Express Centurion Lounge","Annies Cafe & Bar": "Annie's Cafe & Bar","Apparel and Gifts": "Apparel & Gifts","Applebee's Grill + Bar": "Applebee's Grill & Bar","Arrowhead Grab n Go": "Arrowhead Grab & Go","Arrowhead Taphouse": "Arrowhead Tap House","Art - Pioneers of Aviation Exhibit": "Pioneers of Aviation Exhibit","Asian Street Eats": "Asian Street Eat","Auntie Anne's": "Auntie Anne's Pretzels","Automated Rental Lounge": "Automated Rental","Available Ticket Counter Space": "Available Ticket Counter","Aviation Admin Offices": "Aviation Administration Office","Aviator's": "Aviator","Avis Airlines": "Avis Car Rental","B Grill by BOA Steakhouse": "B Grill","BLD": "BLD Kitchen","BUILT": "BUILT Custom Burgers & Cocktails","BZN Market": "BZN Market","Bacon Bacon": "Bacon","Badging Room": "Badging","Bag Claim Office": "Baggage Claim","Bag Handling": "Baggage Handling","Bagel Bakery": "Bagel","Baggage Claim": "Baggage Claim","Baggage Service": "Baggage Service","Baggage Service Office": "Baggage Service","Baggage Service Offices": "Baggage Service","Bar & Gril": "Bar & Grill","Bar Escape Lounge": "Bar Escape","Bar Heinold's First and Last Chance": "Bar Heinold's","Barney's Beanery": "Barney's","Barney's Lounge": "Barney's","Barry's Pizza": "Barry's","Barton Springs Express Nook": "Barton Springs Express","Baskin Robbins": "Baskin-Robbins","Beads on the Vine": "Beads on the Vine","Beaudevin": "Beaudevin Wine Bar","Bellevue Essentials": "Bellevue","Berry Austin": "Berry","Berry J Centine Conference Room": "Berry J Centine Conference Room","Best Buy Express": "Best Buy","Betcha Burger": "Betcha","Beverages and food": "Beverages & Food","Beverages and food & Gift": "Beverages & Food & Gifts","Beverages and food & Gift & News": "Beverages & Food & Gifts & News","Bigelow Labs Tiny Giants": "Bigelow Labs","Bistrot Bay Area": "Bistrot","Black Bear Saloon": "Black Bear","Black Mesa Coffee": "Black Mesa","Blu2o": "Blu 2.0","Blue Bar": "Blue","Blue Ride Navern": "Blue Ride","Bluegrass Coffee": "Bluegrass","Bluegrass Market": "Bluegrass","Boardwalk Cafe": "Boardwalk Cafe","Bocce Pizza": "Bocce","Book People": "BookPeople","Book Soup": "Book Soup","Border Grill": "Border","Bottle Filing Station": "Bottle Filling Station","Bourbon Pab": "Bourbon Pab","Breeze Air": "Breeze Airways","Breeze Airlines": "Breeze Airways","Bricktown Square": "Bricktown","Bristol Brewing Company": "Bristol Brewing","British Airlines": "British Airways","Brookstone": "Brookstone" ...
# <class 'dict'>
# processing batch
# {"M. Fredric": "M.Fredric","JetBlue Air": "JetBlue Airlines","JetBlue Airlines": "JetBlue Airlines","JetBlue Airlines Bag Claim Office": "JetBlue Airlines Bag Claim Office","JetBlue Crew Lounge": "JetBlue Crew Lounge","Jetbox Market": "Jet Box Market","Jetstream restaurant - Radar bar": "Jetstream Restaurant","Kids Zone": "KidZone","Kids' Spot": "KidZone","Kylie Skin Cosmetics": "Kylie Cosmetics","L.A. Times Newsstand": "LA Times Newsstand","LAMILL Coffee": "La Mill Coffee","Landside Concession": "Landside Concessions","Last Stop! Grab & Go": "Last Stop Grab & Go","Lauderdale News": "Fort Lauderdale News","Lee Wagner Art Gallery": "Lee Wagner Art","Little Free Library": "Little Library","Little Rock Visitors Information": "Little Rock Visitor Information","Long Beach Business Journal": "Long Beach Business","Long Beach News": "Long Beach News","Los Angeles Magazine News": "Los Angeles Magazine","Luggage Carts": "Luggage Cart","MAC Cosmetics": "MAC","Magic City Market": "Magic City","Market 361": "Market 361","Market 8600": "Market 8600","Marlin's Express": "Marlin's","Meals & More": "Meals & More","Meeting Room A": "Meeting Room A","Meeting Room B": "Meeting Room B","Meter/Grete Area": "Meter/Gate Area","Military Courtesy Room": "Military Courtesy","Military Lounge": "Military Lounge","Mini Market": "Mini Market","Misc Shops": "Misc Shop","Mobile Accessories": "Mobile Accessories","Mokulele Airlines": "Mokulele Air","Monsieur Marcel Gourmet Market": "Monsieur Marcel","Monterey Regional Airport Police": "Monterey Regional Police","Mother Room": "Mother's Room","Mountain House Diner": "Mountain House","Mountain Vista Grille & Bar": "Mountain Vista Grill","Move Vending": "Move","Mr. Willie's Shoe Shine": "Mr. Willie's","Myrtle Beach Area Info": "Myrtle Beach Area","NYS Eyewear": "NYS","Nacho Hippo Cantina Maximo": "Nacho Hippo Cantina","Napa Farms Market": "Napa Farms","Napatree Marketplace 7": "Napatree Marketplace","Native by Nyesha": "Native","New England Travel Mart": "New England Travel","New River News": "New River","News & Retail": "News & Retail","News Stand/Gifts": "News & Gifts","NewsLink Fort Lauderdale": "NewsLink","Newsagent Lake Merritt News": "Newsagent","Newsagent Oakland Marketplace": "Newsagent","Newsagent Oakland Tribune News": "Newsagent","Newsagent Relay": "Newsagent","Northwest Airlink": "Northwest Air","Nursing Mother Room": "Nursing Mother","Nursing Pod": "Nursing Pod","Nursing Room": "Nursing Room","nursing room": "Nursing Room","ODOBA Mexican Eats": "ODOBA","OKS Flight Cantina": "OKS Cantina","Ocean State Travel Mart": "Ocean State Travel","Ohana Air": "Ohana","Only in Rhode Island": "Rhode Island","Osteria by Fabio Viviani": "Osteria","PEI WEI Asian Kitchen": "Pei Wei Asian","PGA Tour Grill": "PGA Tour Grill","PGA Tour Shop": "PGA Tour Shop","POPS West": "POPS","Pacifica Breeze Cafe": "Pacifica Breeze","Panda Express": "Panda Express","Pandora": "Pandora","Pannakin": "Pannakin","Papa Gino's": "Papa Gino's","Pappa's Bar-B-Q": "Pappa's BBQ","Pappa's Burger": "Pappa's","Pappadeaux Seafood Kitchen": "Pappadeaux","Pappasito's Cantina": "Pappasito's","Par 3 Bar & Grill": "Par 3 Grill","Paradies Avanti Marcet": "Paradies Avanti","Paradies Shop": "Paradies","Paradies Shops": "Paradies","Parking Counter": "Parking","Parking Garage": "Parking Garage","Parking Help Desk": "Parking Help","Parking Kiosk": "Parking Kiosk","Parking Pay on Foot Kiosk": "Parking Pay","Parkside": "Parkside","Parrilla Grill": "Parrilla","Passenger Holding": "Passenger Holding","Passenger Meet & Greet": "Passenger Meet & Greet","Passport Club": "Passport Club","Passport Control": "Passport Control","Pauli's Lounge": "Pauli's","Pavilion Bar & Grill": "Pavilion Grill","Peet's Coffee & Tea": "Peet's Coffee","Pei Wei": "Pei Wei","Pensacola Beach House": "Pensacola Beach","People News": "People","Perfectly Pennsylvania": "Perfectly PA","Pet Relief Area": "Pet Relief","Pharmacy": "Pharmacy","Phil's BBQ": "Phil's BBQ","Phillips Seafood": "Phillip ...
# <class 'dict'>
# processing last batch
# {"United Baggage Office": "United Baggage Service Office","United Baggage Service Office": "United Baggage Service Office","United Express": "United Airlines","United Global Services": "United Airlines","Vending Machine": "Vending Machines","Vending Machines": "Vending Machines","Vending Mechine": "Vending Machines","Vending machine": "Vending Machines","vending machines": "Vending Machines","Wending Machine": "Vending Machines","jetBlue": "JetBlue Airways","jetBlue Airlines Ticketing": "JetBlue Airways"}
# <class 'dict'>
# replacements: {'United Baggage Office': 'United Baggage Service Office', 'United Express': 'United Airlines', 'United Global Services': 'United Airlines', 'Vending Machine': 'Vending Machines', 'Vending Mechine': 'Vending Machines', 'Vending machine': 'Vending Machines', 'vending machines': 'Vending Machines', 'Wending Machine': 'Vending Machines', 'jetBlue': 'JetBlue Airways', 'jetBlue Airlines Ticketing': 'JetBlue Airways'}
# orig df:      airport_code terminal                           business  \
# 0             bli        1  US CUSTOMS AND BORDERS PROTECTION
# 1             dro        1                Little Free Library
# 2             avp        1    Berry J Centine Conference Room
# 3             abq        1                   Observation Deck
# 4             abq        1          Tech on the Go TTY Phones
# ...           ...      ...                                ...
# 1569          okc        1                                ATM
# 1570          okc        1                                ATM
# 1571          pgd        1                                ATM
# 1572          pvd        1                                ATM
# 1573          pvd        1                                ATM
#
#                 category      location menu_items  _data_source  \
# 0         Administration        Gate 6       None  airportguide
# 1       Airport Facility       Gate 10       None  airportguide
# 2          Meeting Space       Gates 6       None  airportguide
# 3       Airport Facility       Gate A1       None  airportguide
# 4          Communication       Gate A5       None  airportguide
# ...                  ...           ...        ...           ...
# 1569  Financial Services  Near Gate B2       None  airportguide
# 1570  Financial Services  Near Gate B8       None  airportguide
# 1571  Financial Services        Gate 1       None  airportguide
# 1572  Financial Services   Near Gate 9       None  airportguide
# 1573  Financial Services  Near Gate 19       None  airportguide
#
#                            _load_time
# 0    2024-08-25 15:16:58.467182+00:00
# 1    2024-08-25 15:16:58.467182+00:00
# 2    2024-08-25 15:16:58.467182+00:00
# 3    2024-08-25 15:16:58.467182+00:00
# 4    2024-08-25 15:16:58.467182+00:00
# ...                               ...
# 1569 2024-08-25 15:16:58.467182+00:00
# 1570 2024-08-25 15:16:58.467182+00:00
# 1571 2024-08-25 15:16:58.467182+00:00
# 1572 2024-08-25 15:16:58.467182+00:00
# 1573 2024-08-25 15:16:58.467182+00:00
#
# [1574 rows x 8 columns]
# new df:      airport_code terminal                           business  \
# 0             bli        1  US CUSTOMS AND BORDERS PROTECTION
# 1             dro        1                Little Free Library
# 2             avp        1    Berry J Centine Conference Room
# 3             abq        1                   Observation Deck
# 4             abq        1          Tech on the Go TTY Phones
# ...           ...      ...                                ...
# 1569          okc        1                                ATM
# 1570          okc        1                                ATM
# 1571          pgd        1                                ATM
# 1572          pvd        1                                ATM
# 1573          pvd        1                                ATM
#
#                 category      location menu_items  _data_source  \
# 0         Administration        Gate 6       None  airportguide
# 1       Airport Facility       Gate 10       None  airportguide
# 2          Meeting Space       Gates 6       None  airportguide
# 3       Airport Facility       Gate A1       None  airportguide
# 4          Communication       Gate A5       None  airportguide
# ...                  ...           ...        ...           ...
# 1569  Financial Services  Near Gate B2       None  airportguide
# 1570  Financial Services  Near Gate B8       None  airportguide
# 1571  Financial Services        Gate 1       None  airportguide
# 1572  Financial Services   Near Gate 9       None  airportguide
# 1573  Financial Services  Near Gate 19       None  airportguide
#
#                            _load_time
# 0    2024-08-25 15:16:58.467182+00:00
# 1    2024-08-25 15:16:58.467182+00:00
# 2    2024-08-25 15:16:58.467182+00:00
# 3    2024-08-25 15:16:58.467182+00:00
# 4    2024-08-25 15:16:58.467182+00:00
# ...                               ...
# 1569 2024-08-25 15:16:58.467182+00:00
# 1570 2024-08-25 15:16:58.467182+00:00
# 1571 2024-08-25 15:16:58.467182+00:00
# 1572 2024-08-25 15:16:58.467182+00:00
# 1573 2024-08-25 15:16:58.467182+00:00
#
# [1574 rows x 8 columns]
# 100%|██████████| 1/1 [00:00<00:00, 6615.62it/s]

# %%
# %%bigquery
# select * from air_travel_stg.airport_businesses
# order by business desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      airport_code       terminal                    business  \
# 0             lax  international             iStore Boutique
# 1             bdl              1                      iStore
# 2             hou              1                      iStore
# 3             sfo              1                      iStore
# 4             las              1                      iCandy
# ...           ...            ...                         ...
# 1569          lgb              1                    4th Vine
# 1570          sfo              2              49 Mile Market
# 1571          pie              1  3 Daughters Brewing at PIE
# 1572          boi              1   13th Street Pub and Grill
# 1573          psp              1    12th Fairway Bar & Grill
#
#                category
# 0           Electronics
# 1              Shopping
# 2     Electronics Store
# 3           Electronics
# 4           Candy Store
# ...                 ...
# 1569         Restaurant
# 1570           Shopping
# 1571             Dining
# 1572             Dining
# 1573         Restaurant
#
# [1574 rows x 4 columns]

# %% [markdown]
# #### Look for certain unwanted characters in the name of the business

# %%
# %%bigquery
# select * from air_travel_stg.airport_businesses
# where business like '“%'
# order by business
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   airport_code terminal          business       category  \
# 0          sba        1           “Fiesta  Entertainment
# 1          sba        1  “Good Time Clock  Entertainment
# 2          sba        1    “SB Sky Gazing  Entertainment
#
#                    location menu_items  _data_source  \
# 0             Near gates G3       None  airportguide
# 1  Near Car Rental National       None  airportguide
# 2             Near gates G3       None  airportguide
#
#                         _load_time
# 0 2024-08-25 15:16:58.467182+00:00
# 1 2024-08-25 15:16:58.467182+00:00
# 2 2024-08-25 15:16:58.467182+00:00

# %% [markdown]
# #### Create staging table and remove unwanted characters

# %%
# %%bigquery
# create or replace table air_travel_stg.airport_businesses as
#     select airport_code, terminal, replace(business, '“', '') as business,
#       category, location, menu_items, _data_source, _load_time
#     from air_travel_stg.airport_businesses
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from air_travel_stg.airport_businesses
# where business like '“%'
# order by business
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [airport_code, terminal, business, category, location, menu_items, _data_source, _load_time]
# Index: []

# %% [markdown]
# #### Cleanup

# %%
# %%bigquery
# drop table air_travel_stg.tmp_airport_businesses
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airport_reviews` table

# %% [markdown]
# #### Rename fields and create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.airport_reviews as
# 	select id,
# 	threadRef as thread_id,
# 	airportRef as airport_id,
# 	airportIdent as airport_code,
# 	date as date_created,
# 	memberNickname as author,
# 	subject,
# 	body,
# 	_data_source,
# 	_load_time
# 	from air_travel_raw.airport_reviews
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airports` table

# %% [markdown]
# #### Profile `source` and `type` fields

# %%
# %%bigquery
# select count(*) source_count
# from air_travel_raw.airports
# where source != '\\N' and source is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    source_count
# 0         11017

# %%
# %%bigquery
# select count(*) type_count
# from air_travel_raw.airports
# where type != '\\N' and type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    type_count
# 0       11017

# %%
# %%bigquery
# select distinct source
# from air_travel_raw.airports
# where source != '\\N' and source is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         source
# 0         User
# 1       Legacy
# 2  OurAirports

# %%
# %%bigquery
# select distinct type
# from air_travel_raw.airports
# where type != '\\N' and type is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       type
# 0  unknown
# 1  airport
# 2  station
# 3     port

# %%
# %%bigquery
# 	select safe_cast(airport_id as INTEGER) as airport_id,
# 	airport_name,
# 	city,
# 	country,
# 	case iata
# 		when '\\N' then null
# 		else iata
# 		end as iata,
# 	case icao
# 		when '\\N' then null
# 		else icao
# 		end as icao,
# 	latitude,
# 	longitude,
# 	altitude,
# 	safe_cast(timezone as INTEGER) as timezone_delta,
#   daylight_savings_time,
#   case tz_database_timezone
# 		when '\\N' then null
# 		else tz_database_timezone
# 		end as timezone_name,
# 	case type
# 		when '\\N' then null
# 		else type
# 		end as type,
# 	case source
# 		when '\\N' then null
# 		else source
# 		end as source,
# 	_data_source
# 	_load_time
# 	from air_travel_raw.airports
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        airport_id                 airport_name                 city  \
# 0           11746                    Kona Dock   Kailua-Kona Hawaii
# 1           12060             Kanuhuraa Island     Kanuhuraa Island
# 2           12061               Kwara Airstrip           Kwara Camp
# 3           12062                Matemo Island        Matemo Island
# 4           12063              Medjumbe Island      Medjumbe Island
# ...           ...                          ...                  ...
# 12663        2500           Santa Cruz Airport           Santa Cruz
# 12664        4061          El Calafate Airport          El Calafate
# 12665        6028            Las Heras Airport            Las Heras
# 12666        6030       Lago Argentino Airport          El Calafate
# 12667        6031  Gobernador Gregores Airport  Gobernador Gregores
#
#              country  iata  icao                                    latitude  \
# 0      United States  None  None   19.63858700000000000000000000000000000000
# 1           Maldives  None  None    5.53413100000000000000000000000000000000
# 2           Botswana  None  None  -19.10142900000000000000000000000000000000
# 3         Mozambique  None  None  -12.20077300000000000000000000000000000000
# 4         Mozambique  None  None  -11.81743200000000000000000000000000000000
# ...              ...   ...   ...                                         ...
# 12663      Argentina   RZA  SAWU  -50.01650000000000000000000000000000000000
# 12664      Argentina   FTE  SAWC  -50.28030000000000000000000000000000000000
# 12665      Argentina   LHS  SAVH  -46.53829956049999000000000000000000000000
# 12666      Argentina   ING  SAWA  -50.33610200000000000000000000000000000000
# 12667      Argentina   GGS  SAWR  -48.78310000000000000000000000000000000000
#
#                                          longitude  altitude  timezone_delta  \
# 0      -155.99673900000000000000000000000000000000         0             -10
# 1        73.50598100000000000000000000000000000000         0               5
# 2        23.28379800000000000000000000000000000000         0               1
# 3        40.56896900000000000000000000000000000000         0               1
# 4        40.60365600000000000000000000000000000000         0               1
# ...                                            ...       ...             ...
# 12663   -68.57920000000000000000000000000000000000       364              -3
# 12664   -72.05310100000000000000000000000000000000       669              -3
# 12665   -68.96530151370000000000000000000000000000      1082              -3
# 12666   -72.24859600000000000000000000000000000000       732              -3
# 12667   -70.15000200000000000000000000000000000000       356              -3
#
#       daylight_savings_time                   timezone_name     type  \
# 0                         A                            None     None
# 1                         N                            None     None
# 2                         U                            None     None
# 3                         U                            None     None
# 4                         U                            None     None
# ...                     ...                             ...      ...
# 12663                     N  America/Argentina/Rio_Gallegos  airport
# 12664                     N  America/Argentina/Rio_Gallegos  airport
# 12665                     N  America/Argentina/Rio_Gallegos  airport
# 12666                     N  America/Argentina/Rio_Gallegos  airport
# 12667                     N  America/Argentina/Rio_Gallegos  airport
#
#             source   _load_time
# 0             None  openflights
# 1             None  openflights
# 2             None  openflights
# 3             None  openflights
# 4             None  openflights
# ...            ...          ...
# 12663  OurAirports  openflights
# 12664  OurAirports  openflights
# 12665  OurAirports  openflights
# 12666  OurAirports  openflights
# 12667  OurAirports  openflights
#
# [12668 rows x 15 columns]

# %%
# %%bigquery
# select count(*) as type_not_null
# from air_travel_raw.airports
# where type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    type_not_null
# 0          12668

# %%
# %%bigquery
# select count(*) as source_not_null
# from air_travel_raw.airports
# where source is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    source_not_null
# 0            12668

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.airports as
# 	select safe_cast(airport_id as INTEGER) as airport_id,
# 	airport_name,
# 	city,
# 	country,
# 	case iata
# 		when '\\N' then null
# 		else iata
# 		end as iata,
# 	case icao
# 		when '\\N' then null
# 		else icao
# 		end as icao,
# 	latitude,
# 	longitude,
# 	altitude,
# 	safe_cast(timezone as INTEGER) as timezone_delta,
#   daylight_savings_time,
#   case tz_database_timezone
# 		when '\\N' then null
# 		else tz_database_timezone
# 		end as timezone_name,
# 	case type
# 		when '\\N' then null
# 		else type
# 		end as type,
# 	case source
# 		when '\\N' then null
# 		else source
# 		end as source,
# 	_data_source,
# 	_load_time
# 	from air_travel_raw.airports
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `countries` table

# %% [markdown]
# ##### Profile `country_name`, `iso_code`, and `dafif_code`

# %%
# %%bigquery
# select count(*) as empty_country_name
# from air_travel_raw.countries
# where country_name = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_country_name
# 0                   0

# %%
# %%bigquery
# select count(*) as empty_iso_code
# from air_travel_raw.countries
# where iso_code = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_iso_code
# 0              19

# %%
# %%bigquery
# select count(*) as empty_dafif_code
# from air_travel_raw.countries
# where dafif_code = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_dafif_code
# 0                 0

# %% [markdown]
# #### Replace `'\\N'` with null

# %%
# %%bigquery
# select country_name as name,
# case iso_code
#   when '\\N' then null
#   else iso_code
#   end as iso_code,
# dafif_code
# from air_travel_raw.countries
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      name iso_code dafif_code
# 0    United Arab Emirates       AE         AE
# 1             Afghanistan       AF         AF
# 2     Antigua and Barbuda       AG         AC
# 3                Anguilla       AI         AV
# 4                 Albania       AL         AL
# ..                    ...      ...        ...
# 256        Midway Islands     None         MQ
# 257       Paracel Islands     None         PF
# 258       Spratly Islands     None         PG
# 259       Tromelin Island     None         TE
# 260           Wake Island     None         WQ
#
# [261 rows x 3 columns]

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.countries as
#     select country_name as name,
#     case iso_code
#       when '\\N' then null
#       else iso_code
#       end as iso_code,
#     dafif_code,
#     _data_source,
#     _load_time
#     from air_travel_raw.countries
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `flight_delays` table

# %%
# %%bigquery
# select airport_name
# from air_travel_raw.flight_delays
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                         airport_name
# 0                   Albany, NY: Albany International
# 1  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 2  Birmingham, AL: Birmingham-Shuttlesworth Inter...
# 3           Burlington, VT: Burlington International
# 4         Buffalo, NY: Buffalo Niagara International

# %% [markdown]
# #### Split `airport_name` into three components: city, state, airport

# %%
# %%bigquery
# select split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport
# from air_travel_raw.flight_delays
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        city_state                                    airport
# 0      Albany, NY                       Albany International
# 1     Atlanta, GA   Hartsfield-Jackson Atlanta International
# 2  Birmingham, AL     Birmingham-Shuttlesworth International
# 3  Burlington, VT                   Burlington International
# 4     Buffalo, NY              Buffalo Niagara International

# %%
# %%bigquery
# select split(city_state, ',')[0] as city, split(city_state, ',')[1] as state, airport
# from
#   (select split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport
#   from air_travel_raw.flight_delays
#   limit 5)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          city state                                    airport
# 0      Albany    NY                       Albany International
# 1     Atlanta    GA   Hartsfield-Jackson Atlanta International
# 2  Birmingham    AL     Birmingham-Shuttlesworth International
# 3  Burlington    VT                   Burlington International
# 4     Buffalo    NY              Buffalo Niagara International

# %% [markdown]
# #### Putting it all together

# %%
# %%bigquery
# select event_month, carrier, carrier_name, airport_code,
#   split(city_state, ',')[0] as airport_city, split(city_state, ',')[1] as airport_state,
#   airport_name, * except (event_month, carrier, carrier_name, airport_code, airport_name, city_state)
# from
#   (select date(year, month, 01) as event_month, carrier, carrier_name, airport as airport_code,
#   split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport_name,
#   safe_cast(arr_flights as INTEGER) as arr_total, safe_cast(arr_cancelled as INTEGER) as arr_cancelled,
#   safe_cast(arr_diverted as INTEGER) as arr_diverted, safe_cast(arr_delay as INTEGER) as arr_delay_min,
#   safe_cast(weather_delay as INTEGER) as weather_delay_min, safe_cast(nas_delay as INTEGER) as nas_delay_min,
#   safe_cast(late_aircraft_delay as INTEGER) as late_aircraft_delay_min, _data_source, _load_time
#   from air_travel_raw.flight_delays
#   limit 5)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   event_month carrier       carrier_name airport_code airport_city  \
# 0  2024-04-01      9E  Endeavor Air Inc.          ALB       Albany
# 1  2024-04-01      9E  Endeavor Air Inc.          ATL      Atlanta
# 2  2024-04-01      9E  Endeavor Air Inc.          BHM   Birmingham
# 3  2024-04-01      9E  Endeavor Air Inc.          BTV   Burlington
# 4  2024-04-01      9E  Endeavor Air Inc.          BUF      Buffalo
#
#   airport_state                               airport_name  arr_total  \
# 0            NY                       Albany International        115
# 1            GA   Hartsfield-Jackson Atlanta International       2032
# 2            AL     Birmingham-Shuttlesworth International         95
# 3            VT                   Burlington International        142
# 4            NY              Buffalo Niagara International        193
#
#    arr_cancelled  arr_diverted  arr_delay_min  weather_delay_min  \
# 0              0             0            865                 41
# 1              3             1          16233               1528
# 2              1             0            898                 55
# 3              5             1           1546                  9
# 4              1             1            668                 60
#
#    nas_delay_min  late_aircraft_delay_min _data_source  \
# 0             88                      219    transtats
# 1           1745                     7223    transtats
# 2            130                      610    transtats
# 3            121                     1260    transtats
# 4            197                      184    transtats
#
#                         _load_time
# 0 2024-08-25 15:45:31.691980+00:00
# 1 2024-08-25 15:45:31.691980+00:00
# 2 2024-08-25 15:45:31.691980+00:00
# 3 2024-08-25 15:45:31.691980+00:00
# 4 2024-08-25 15:45:31.691980+00:00

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.flight_delays as
#     select event_month, carrier, carrier_name, airport_code,
#     split(city_state, ',')[0] as airport_city, split(city_state, ',')[1] as airport_state,
#     airport_name, * except (event_month, carrier, carrier_name, airport_code, airport_name, city_state)
#     from
#         (select date(year, month, 01) as event_month, carrier, carrier_name, airport as airport_code,
#           split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport_name,
#           safe_cast(arr_flights as INTEGER) as arr_total, safe_cast(arr_cancelled as INTEGER) as arr_cancelled,
#           safe_cast(arr_diverted as INTEGER) as arr_diverted, safe_cast(arr_delay as INTEGER) as arr_delay_min,
#           safe_cast(weather_delay as INTEGER) as weather_delay_min, safe_cast(nas_delay as INTEGER) as nas_delay_min,
#           safe_cast(late_aircraft_delay as INTEGER) as late_aircraft_delay_min, _data_source, _load_time
#           from air_travel_raw.flight_delays)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `flight_routes` table

# %% [markdown]
# #### Profile `source_airport`, `source_airport_id`, `dest_airport`, `dest_airport_id`

# %%
# %%bigquery
# select count(*) as empty_source_airport
# from air_travel_raw.flight_routes
# where source_airport = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_source_airport
# 0                     0

# %%
# %%bigquery
# select count(*) as empty_source_airport_id
# from air_travel_raw.flight_routes
# where source_airport_id = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_source_airport_id
# 0                      220

# %%
# %%bigquery
# select count(*) as empty_dest_airport
# from air_travel_raw.flight_routes
# where dest_airport = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_dest_airport
# 0                   0

# %%
# %%bigquery
# select count(*) as empty_dest_airport_id
# from air_travel_raw.flight_routes
# where dest_airport_id = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_dest_airport_id
# 0                    221

# %% [markdown]
# #### Cast airline_id, replace `'\\N'` with null and rename airport fields

# %%
# %%bigquery
# select airline_code,
#   safe_cast(airline_id as INTEGER) as airline_id,
#   source_airport as source_airport_code,
#   case source_airport_id
#     when '\\N' then null
#     else safe_cast(source_airport_id as INTEGER)
#     end as source_airport_id,
#   dest_airport as dest_airport_code,
#   case dest_airport_id
#     when '\\N' then null
#     else safe_cast(dest_airport_id as INTEGER)
#     end as dest_airport_id,
#   codeshare,
#   stops,
#   equipment,
#   _data_source,
#   _load_time
# from air_travel_raw.flight_routes
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   airline_code  airline_id source_airport_code  source_airport_id  \
# 0           2B         410                 AER               2965
# 1           2B         410                 ASF               2966
# 2           2B         410                 ASF               2966
# 3           2B         410                 CEK               2968
# 4           2B         410                 CEK               2968
#
#   dest_airport_code  dest_airport_id  codeshare  stops equipment _data_source  \
# 0               KZN             2990       <NA>      0       CR2  openflights
# 1               KZN             2990       <NA>      0       CR2  openflights
# 2               MRV             2962       <NA>      0       CR2  openflights
# 3               KZN             2990       <NA>      0       CR2  openflights
# 4               OVB             4078       <NA>      0       CR2  openflights
#
#                         _load_time
# 0 2024-08-25 16:19:41.311112+00:00
# 1 2024-08-25 16:19:41.311112+00:00
# 2 2024-08-25 16:19:41.311112+00:00
# 3 2024-08-25 16:19:41.311112+00:00
# 4 2024-08-25 16:19:41.311112+00:00

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.flight_routes as
#   select airline_code,
#     safe_cast(airline_id as INTEGER) as airline_id,
#     source_airport,
#     case source_airport_id
#       when '\\N' then null
#       else safe_cast(source_airport_id as INTEGER)
#       end as source_airport_id,
#     dest_airport,
#     case dest_airport_id
#       when '\\N' then null
#       else safe_cast(dest_airport_id as INTEGER)
#       end as dest_airport_id,
#     codeshare,
#     stops,
#     equipment,
#     _data_source,
#     _load_time
#   from air_travel_raw.flight_routes
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `tsa_traffic` table

# %% [markdown]
# #### Cast `date` from STRING to DATE

# %%
# %%bigquery
# select date as orig_date, safe_cast(date as DATE) as new_date
# from air_travel_raw.tsa_traffic
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orig_date new_date
# 0   5/8/2024      NaT
# 1  7/24/2024      NaT
# 2  3/27/2024      NaT
# 3  8/17/2022      NaT
# 4   6/7/2023      NaT

# %%
# %%bigquery
# select date as orig_date, safe_cast(date as DATE format 'MM/DD/YYYY') as new_date
# from air_travel_raw.tsa_traffic
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orig_date    new_date
# 0   5/8/2024  2024-05-08
# 1  7/24/2024  2024-07-24
# 2  3/27/2024  2024-03-27
# 3  8/17/2022  2022-08-17
# 4   6/7/2023  2023-06-07

# %% [markdown]
# #### Putting it all together

# %%
# %%bigquery
# select safe_cast(date as DATE format 'MM/DD/YYYY') as event_date,
#   safe_cast(hour as INTEGER) as event_hour,
#   airport_code,
#   airport_name,
#   city as airport_city,
#   state as airport_state,
#   checkpoint as tsa_checkpoint,
#   total_count as passenger_count
# from air_travel_raw.tsa_traffic
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    event_date  event_hour airport_code            airport_name airport_city  \
# 0  2024-05-08          12          ADK                    Adak         Adak
# 1  2024-07-24          13          ADK                    Adak         Adak
# 2  2024-03-27          12          ADK                    Adak         Adak
# 3  2022-08-17          13          ADK  Adak Naval Air Station         Adak
# 4  2023-06-07          12          ADK  Adak Naval Air Station         Adak
#
#   airport_state tsa_checkpoint  passenger_count
# 0            AK    Checkpoint1               23
# 1            AK    Checkpoint1                1
# 2            AK    Checkpoint1                7
# 3            AK    Checkpoint1               67
# 4            AK    Checkpoint1                3

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.tsa_traffic as
#   select safe_cast(date as DATE format 'MM/DD/YYYY') as event_date,
#     safe_cast(hour as INTEGER) as event_hour,
#     airport_code,
#     airport_name,
#     city as airport_city,
#     state as airport_state,
#     checkpoint as tsa_checkpoint,
#     total_count as passenger_count,
#     _data_source,
#     _load_time
#   from air_travel_raw.tsa_traffic
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
